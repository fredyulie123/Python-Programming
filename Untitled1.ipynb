# %%
pip install easygui
# Out:
# Requirement already satisfied: easygui in c:\anaconda\lib\site-packages (0.98.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import easygui as g
import os

# %%
type_file_dict = {}
count_line_dict = {}

ext_all = ['.R','.py', '.ipynb']

def search(path):
    os.chdir(path)
    all_files = os.listdir(os.curdir)
    for each_file in all_files:
        ext = os.path.splitext(each_file)[1]
        if ext in ext_all:
            type_file(ext)
            count_line(each_file,ext)
            
        if os.path.isdir(each_file):
            search(each_file)
            os.chdir(os.pardir)
            
                
def type_file(ext):
    type_file_dict.setdefault(ext,0)
    type_file_dict[ext]+=1
    
def count_line(each_file,ext):
    try:
        f = open(each_file,encoding='UTF-8')
        print('正在分析文件：%s ...' % each_file)
        for each in f.read():
            count_line_dict.setdefault(ext,0)
            count_line_dict[ext] +=1
        f.close()
    except FileNotFoundError:
        pass
    

def show():
    
    All = 0
    for each in count_line_dict.values():
        All+=each
    str1 =''
    rest = 100000 - All
    p = All/1000
    
    msg='您目前共累积编写了'+str(All)+'行代码，完成进度:%.2f%%'%p+'\n离10万行代码还差'+str(rest)+'行，请继续努力！'
    title='统计结果'
    
    for each in count_line_dict.keys():
        str1=str1+'【'+each+'】源文件'+str(type_file_dict[each])+'个,源代码'+str(count_line_dict[each])+'行\n'
        
    
    g.textbox(msg,title,str1)    

dir1=g.diropenbox(msg='请选择您的代码库：')



search(dir1)
show()
# Out:
# 正在分析文件：1.2 Practice problems-checkpoint.ipynb ...
# 正在分析文件：11.1 Power laws (student)-checkpoint.ipynb ...
# 正在分析文件：11.1 Power laws-checkpoint.ipynb ...
# 正在分析文件：5.1 Scraping whitehouse briefings and statements-checkpoint.ipynb ...
# 正在分析文件：Homework 1-checkpoint.ipynb ...
# 正在分析文件：L01.1.1 Numbers, Object Assignment, Strings-checkpoint.ipynb ...
# 正在分析文件：Lab 3_1_Yelp_review_BeautifulSoup-checkpoint.ipynb ...
# 正在分析文件：Lab 3_2_Twitter_keywords_tweepy-checkpoint.ipynb ...
# 正在分析文件：Python section2-checkpoint.ipynb ...
# 正在分析文件：Untitled-checkpoint.ipynb ...
# 正在分析文件：Untitled2-checkpoint.ipynb ...
# 正在分析文件：Yifeng He Parser Homework2-checkpoint.ipynb ...
# 正在分析文件：Yifeng He Parser Hw2 - Copy-checkpoint.ipynb ...
# 正在分析文件：Yifeng He Parser Hw2-checkpoint.ipynb ...
# 正在分析文件：Yifeng He Parser-checkpoint.ipynb ...
# 正在分析文件：11.1 Power laws (student).ipynb ...
# 正在分析文件：11.1 Power laws.ipynb ...
# 正在分析文件：4.1 Scraping AFs papers.ipynb ...
# 正在分析文件：4.2 Scraping 3 most freq.py ...
# 正在分析文件：4.3 Methods, Functions, Importing and Making modules (self study).ipynb ...
# 正在分析文件：5.0 Getting started with Selenium.py ...
# 正在分析文件：5.1 Scraping my papers with BS.py ...
# 正在分析文件：5.1 Scraping whitehouse briefings and statements.ipynb ...
# 正在分析文件：5.3 Getting started with Selenium.py ...
# 正在分析文件：5.3 Logging in with Selenium.py ...
# 正在分析文件：5.4 Logging in with Selenium.py ...
# 正在分析文件：5.5 Navigating around a webpage with Selenium.py ...
# 正在分析文件：5.6 Scraping tweets with Selenium.py ...
# 正在分析文件：8.1 Text Analytics.ipynb ...
# 正在分析文件：autohome-checkpoint.ipynb ...
# 正在分析文件：Untitled-checkpoint.ipynb ...
# 正在分析文件：Untitled1-checkpoint.ipynb ...
# 正在分析文件：Untitled2-checkpoint.ipynb ...
# 正在分析文件：Untitled3-checkpoint.ipynb ...
# 正在分析文件：Untitled4-checkpoint.ipynb ...
# 正在分析文件：Untitled5-checkpoint.ipynb ...
# 正在分析文件：Untitled6-checkpoint.ipynb ...
# 正在分析文件：Untitled7-checkpoint.ipynb ...
# 正在分析文件：Untitled8-checkpoint.ipynb ...
# 正在分析文件：Untitled9-checkpoint.ipynb ...
# 正在分析文件：will be parsed hotel-checkpoint.ipynb ...
# 正在分析文件：merge.py ...
# 正在分析文件：neuralnetwork_sentiment.py ...
# 正在分析文件：scrape.py ...
# 正在分析文件：sentiment.py ...
# 正在分析文件：textProcessing.py ...
# 正在分析文件：Untitled-checkpoint.ipynb ...
# 正在分析文件：Untitled1-checkpoint.ipynb ...
# 正在分析文件：Untitled2-checkpoint.ipynb ...
# 正在分析文件：Untitled3-checkpoint.ipynb ...
# 正在分析文件：Untitled4-checkpoint.ipynb ...
# 正在分析文件：Untitled5-checkpoint.ipynb ...
# 正在分析文件：deep_learning_sentiment.py ...
# 正在分析文件：machine_learning_sentiment.py ...
# 正在分析文件：merge_text.py ...
# 正在分析文件：scrape.py ...
# 正在分析文件：textProcessing.py ...
# 正在分析文件：Untitled.ipynb ...
# 正在分析文件：Untitled1.ipynb ...
# 正在分析文件：Untitled2.ipynb ...
# 正在分析文件：Untitled3.ipynb ...
# 正在分析文件：Untitled4.ipynb ...
# 正在分析文件：Untitled5.ipynb ...
# 正在分析文件：merge.py ...
# 正在分析文件：practice.py ...
# 正在分析文件：scrape.py ...
# 正在分析文件：sentiment.py ...
# 正在分析文件：textProcessing.py ...
# 正在分析文件：Untitled.ipynb ...
# 正在分析文件：Untitled1.ipynb ...
# 正在分析文件：Untitled2.ipynb ...
# 正在分析文件：Untitled3.ipynb ...
# 正在分析文件：Untitled4.ipynb ...
# 正在分析文件：Untitled5.ipynb ...
# 正在分析文件：will be parsed hotel.ipynb ...
# 正在分析文件：Untitled-checkpoint.ipynb ...
# 正在分析文件：Untitled1-checkpoint.ipynb ...
# 正在分析文件：autohome.ipynb ...
# 正在分析文件：autohome_transfile.ipynb ...
# 正在分析文件：Untitled.ipynb ...
# 正在分析文件：Untitled1.ipynb ...
# 正在分析文件：Untitled6.ipynb ...
# 正在分析文件：Untitled7.ipynb ...
# 正在分析文件：Untitled8.ipynb ...
# 正在分析文件：Hello World.ipynb ...
# 正在分析文件：Homework 1.ipynb ...
# 正在分析文件：Lab 3_1_Yelp_review_BeautifulSoup.ipynb ...
# 正在分析文件：Lab 3_2_Twitter_keywords_tweepy.ipynb ...
# 正在分析文件：1.3 Practice problems (solutions)-checkpoint.ipynb ...
# 正在分析文件：1.2 Practice problems.ipynb ...
# 正在分析文件：1.3 Practice problems (solutions).ipynb ...
# 正在分析文件：first notebook.ipynb ...
# 正在分析文件：L01.1.1 Numbers, Object Assignment, Strings.ipynb ...
# 正在分析文件：2.2 Practice problems-checkpoint.ipynb ...
# 正在分析文件：2.3 Practice problems (solutions)-checkpoint.ipynb ...
# 正在分析文件：2.4 Assignment by reference and value (self study)-checkpoint.ipynb ...
# 正在分析文件：2.5 Sets (self study)-checkpoint.ipynb ...
# 正在分析文件：loops files working with data-checkpoint.ipynb ...
# 正在分析文件：Python section2-checkpoint.ipynb ...
# 正在分析文件：2.1 Lists, Dictionaries, Comparison, Conditionals.ipynb ...
# 正在分析文件：2.2 Practice problems.ipynb ...
# 正在分析文件：2.3 Practice problems (solutions).ipynb ...
# 正在分析文件：2.4 Assignment by reference and value (self study).ipynb ...
# 正在分析文件：2.5 Sets (self study).ipynb ...
# 正在分析文件：loops files working with data.ipynb ...
# 正在分析文件：Python section2.ipynb ...
# 正在分析文件：3.1 Loops, files, and working with data-checkpoint.ipynb ...
# 正在分析文件：3.3 Practice problems (solutions)-checkpoint.ipynb ...
# 正在分析文件：3.1 Loops, files, and working with data.ipynb ...
# 正在分析文件：3.2 Practice problems.ipynb ...
# 正在分析文件：3.3 Practice problems (solutions).ipynb ...
# 正在分析文件：6.1 Learning a linear model from data (linear regression)-checkpoint.ipynb ...
# 正在分析文件：6.2 Learning a non-linear model from data (decision trees)-checkpoint.ipynb ...
# 正在分析文件：6.1 Learning a linear model from data (linear regression).ipynb ...
# 正在分析文件：6.2 Learning a non-linear model from data (decision trees).ipynb ...
# 正在分析文件：6.3 Pandas (self study).ipynb ...
# 正在分析文件：9.1 Computing PageRank with Python-checkpoint.ipynb ...
# 正在分析文件：9.1 Computing PageRank with Python.ipynb ...
# 正在分析文件：12.1 Graphs as co-occurence networks (student)-checkpoint.ipynb ...
# 正在分析文件：12.1 Graphs as co-occurence networks (student).ipynb ...
# 正在分析文件：7.1 Evaluating models with Python-checkpoint.ipynb ...
# 正在分析文件：7.1 Evaluating models with Python.ipynb ...
# 正在分析文件：8.1 Text Analytics-checkpoint.ipynb ...
# 正在分析文件：8.1 Text Analytics.ipynb ...
# 正在分析文件：Untitled.ipynb ...
# 正在分析文件：untitled1.py ...
# 正在分析文件：Untitled2.ipynb ...
# 正在分析文件：Xiao_Xue_Parser.py ...
# 正在分析文件：Yifeng He Parser Homework2.ipynb ...
# 正在分析文件：Yifeng He Parser Hw2 - Copy.ipynb ...
# 正在分析文件：Yifeng He Parser Hw2.ipynb ...
# 正在分析文件：Yifeng He Parser.ipynb ...
